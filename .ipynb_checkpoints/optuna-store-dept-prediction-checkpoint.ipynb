# %% [markdown]
# # Library

# %%
import warnings
warnings.filterwarnings("ignore")


import numpy as np
import pandas as pd
import datetime, random, math
from catboost import CatBoostClassifier
import lightgbm as lgb
from time import time
from tqdm import tqdm
from collections import Counter
from scipy import stats
import gc, pickle
import ast

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GroupKFold, GridSearchCV, train_test_split, TimeSeriesSplit
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, log_loss
from sklearn.linear_model import Ridge,Lasso, BayesianRidge
from sklearn.svm import LinearSVR
from sklearn.preprocessing import minmax_scale
from sklearn.cluster import KMeans
import optuna
# %matplotlib inline

# %% [markdown]
# # Preprocessing

# %%
def create_is_sell_data(sell_prices_df, calendar_df, train_df):
    train_df.index = train_df['id']
    sell_prices_df['id'] = sell_prices_df['item_id'].astype('str')+'_'+sell_prices_df['store_id']+'_evaluation'
    sell_prices_data = sell_prices_df[sell_prices_df.wm_yr_wk.isin(calendar_df.wm_yr_wk.unique())]
    sell_prices_data.reset_index(drop=True, inplace=True)
    tmp = sell_prices_data.groupby(['id'])[['wm_yr_wk', 'sell_price']].apply(
        lambda x: x.set_index('wm_yr_wk')['sell_price'].to_dict()
    ).to_dict()
    d = calendar_df.d
    wm_yr_wk = calendar_df.wm_yr_wk
    price_data = {}
    for col in tqdm(train_df.id.unique()):
        price_data[col] = wm_yr_wk.map(tmp[col])
    price_data = pd.DataFrame(price_data)
    price_data.index = d
    is_sell = price_data.notnull().astype(float).T
    price_data = price_data.fillna(0)
    
    is_sell.index=train_df.id
    train_df.index=train_df.id
    is_sell = pd.concat([
        train_df[['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']], is_sell
    ], axis=1)
    price_data = pd.concat([
        train_df[['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']], price_data.T  
    ], axis=1)
    
    return price_data, is_sell

def sort_d_cols(d_cols):
    d_cols = [int(d.replace('d_','')) for d in d_cols]
    d_cols = sorted(d_cols)
    d_cols = [f'd_{d}' for d in d_cols]
    return d_cols


path='/Users/abcdm/Downloads/m5-forecasting-accuracy/'
train = pd.read_csv(path+'sales_train_evaluation.csv')
calendar = pd.read_csv(path+'calendar.csv')
price = pd.read_csv(path+'sell_prices.csv')
price_data, is_sell = create_is_sell_data(price, calendar, train)
d_cols = [f'd_{i+1}' for i in range(1969)]
train = train.reindex(
    columns=['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']+d_cols
)
train = train.set_index('id', drop=False)
train = pd.concat([
    train[['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']],
    train[d_cols]*price_data[d_cols]
], axis=1)


def sale_by_group(ID, data, train, trn_d_cols, group='state_id'):
    for _id in train[group].unique():
        f = train[train[group]==_id].groupby(ID)[trn_d_cols].sum(min_count=1).T
        f = f.stack(dropna=False).reset_index().rename(columns={0:f'TARGET_{_id}', 'level_0':'d'})
        data = pd.merge(data, f, on=['d', ID])
    return data

def cnt_by_group(ID, data, price_data, trn_d_cols, group='state_id'):
    for _id in price_data[group].unique():
        f = price_data[price_data[group]==_id].replace(0, np.nan).groupby(ID)[trn_d_cols].count().T
        f = f.stack(dropna=False).reset_index().rename(columns={0:f'cnt_{_id}', 'level_0':'d'})
        data = pd.merge(data, f, on=['d', ID])
    return data


def fe(ID,data, log=False):
    target_cols = [col for col in data.columns if 'TARGET' in col]
    for target_col in target_cols:
        if log:
            data[target_col] = np.log1p(data[target_col])
        for win in [7,28]:
            agg = {'mean'}
            data_2 = data.groupby(ID)[target_col].apply(
                lambda x: x.rolling(win, min_periods=1).agg(agg)
            )
            for col in data_2.columns:
                data[f'roll{win}_{col}_{target_col}'] = data_2[col]
        #data[f'roll28_mean_{target_col}_lag28'] = data.groupby(ID)[f'roll28_mean_{target_col}'].shift(28)
        data[f'roll28_mean_{target_col}_lag56'] = data.groupby(ID)[f'roll28_mean_{target_col}'].shift(56)
        data[f'roll28_mean_{target_col}_lag84'] = data.groupby(ID)[f'roll28_mean_{target_col}'].shift(84)
        
        for i in range(0,10,2):
                data[f'shift{7*(i+1)}_{target_col}'] = data.groupby(ID)[target_col].shift(7*i)
                
        data[f'shift_diff_{target_col}']=0
        for i in range(4):
                data[f'shift_diff_{target_col}'] += data.groupby(ID)[target_col].diff(7*i)/4

    data_2 = data.groupby(ID)['TARGET'].apply(
                lambda x: x.rolling(4, min_periods=1).mean().rolling(21, min_periods=1).agg({'std'})
            )
    for col in data_2.columns:
                data[f'smth_roll28_{col}_TARGET'] = data_2[col]
    
    del_f = [col for col in target_cols if col!='TARGET']
    data.drop(columns=del_f, inplace=True)
    
    return data


def select_near_event(x, event_name):
    z = ''
    for y in x:
        if y in event_name:
            z+=y+'_'
    if len(z)==0:
        return np.nan
    else:
        return z
    
    
calendar['qaurter'] = pd.to_datetime(calendar['date']).dt.day.apply(lambda x: x//7)

event_name = ['SuperBowl', 'ValentinesDay', 'PresidentsDay', 'LentStart', 'LentWeek2', 'StPatricksDay', 'Purim End', 
              'OrthodoxEaster', 'Pesach End', 'Cinco De Mayo', "Mother's day", 'MemorialDay', 'NBAFinalsStart', 'NBAFinalsEnd',
              "Father's day", 'IndependenceDay', 'Ramadan starts', 'Eid al-Fitr', 'LaborDay', 'ColumbusDay', 'Halloween', 
              'EidAlAdha', 'VeteransDay', 'Thanksgiving', 'Christmas', 'Chanukah End', 'NewYear', 'OrthodoxChristmas', 
              'MartinLutherKingDay', 'Easter']
event_type = ['Sporting', 'Cultural', 'National', 'Religious']
event_names = {'event_name_1':event_name, 'event_type_1':event_type}
for event, event_name in event_names.items():
    calendar[f'new_{event}']=''
    for i in range(-1,-8,-1):
        calendar[f'new_{event}'] += calendar[event].shift(i).astype(str)+'|'
    calendar[f'new_{event}'] = calendar[f'new_{event}'].apply(lambda x: x.split('|'))
    calendar[f'new_{event}'] = calendar[f'new_{event}'].apply(lambda x: select_near_event(x, event_name))
    
    
def make_data_dept_cat_id(ID, trn_d_cols, train, price_data, calendar, log=True):
    data = train.groupby(ID)[trn_d_cols].sum(min_count=1).T
    data = data.stack(dropna=False).reset_index().rename(columns={0:'TARGET', 'level_0':'d'})
    f = price_data.replace(0,np.nan).groupby(ID)[
        trn_d_cols
    ].count().stack(dropna=False).reset_index().rename(columns={0:'cnt', 'level_1':'d', 'level_0':'d'})
    data = pd.merge(data, f, on=['d', ID])
    data = sale_by_group(ID, data, train, trn_d_cols)

    data = cnt_by_group(ID, data, price_data, trn_d_cols)
    data = fe(ID, data, log=log)

    for key, value in calendar.set_index('d')[['qaurter','wday','month','year','new_event_name_1', 'new_event_type_1','event_name_1','event_type_1','snap_CA','snap_WI','snap_TX']].items():
        data[key] = data.d.map(value)
        if data[key].dtypes==object:
            data[key] = pd.factorize(data[key])[0]

        if key in ['event_name_1','event_type_1','snap_CA','snap_WI','snap_TX']:
            for i in [ -1,1]:
                data[f'{key}_{i}'] = data.groupby(ID)[key].shift(i)

    data[f'f_{ID}'] = pd.factorize(data[ID])[0]
    data = data[data.d.isin(trn_d_cols[28:])]
    return data

def make_data_all_id(ID, trn_d_cols, train, price_data, calendar):
    data = train.groupby(ID)[trn_d_cols].sum(min_count=1).T
    data = data.stack(dropna=False).reset_index().rename(columns={0:'TARGET', 'level_0':'d'})
    f = price_data.replace(0,np.nan).groupby(ID)[
        trn_d_cols
    ].count().stack(dropna=False).reset_index().rename(columns={0:'cnt', 'level_1':'d', 'level_0':'d'})
    data = pd.merge(data, f, on=['d', ID])
    data = sale_by_group(ID, data, train, trn_d_cols, group='state_id')

    data = cnt_by_group(ID, data, price_data, trn_d_cols)
    data = fe(ID, data, log=False)

    for key, value in calendar.set_index('d')[['qaurter','wday','month','year','new_event_name_1', 'new_event_type_1','event_name_1','event_type_1','snap_CA','snap_WI','snap_TX']].items():
        data[key] = data.d.map(value)
        if data[key].dtypes==object:
            data[key] = pd.factorize(data[key])[0]

        if key in ['event_name_1','event_type_1','snap_CA','snap_WI','snap_TX']:
            for i in [ -1,1]:
                data[f'{key}_{i}'] = data.groupby(ID)[key].shift(i)

    data[f'f_{ID}'] = pd.factorize(data[ID])[0]
    data = data[data.d.isin(trn_d_cols[28:])]
    return data
def make_data_state_id_store_id(ID, trn_d_cols, train, price_data, calendar, log=True):
    
    data = train.groupby(ID)[trn_d_cols].sum(min_count=1).T
    data = data.stack(dropna=False).reset_index().rename(columns={0:'TARGET', 'level_0':'d'})
    f = price_data.replace(0,np.nan).groupby(ID)[
        trn_d_cols
    ].count().stack(dropna=False).reset_index().rename(columns={0:'cnt', 'level_1':'d', 'level_0':'d'})
    data = pd.merge(data, f, on=['d', ID])
    
    group='cat_id'
    for _id in train[group].unique():
        f = train[train[group]==_id].groupby(ID)[trn_d_cols].sum(min_count=1).T
        f = f.stack(dropna=False).reset_index().rename(columns={0:f'TARGET_{_id}', 'level_0':'d'})
        data = pd.merge(data, f, on=['d', ID])
    
    for _id in price_data[group].unique():
        f = price_data[price_data[group]==_id].replace(0, np.nan).groupby(ID)[trn_d_cols].count().T
        f = f.stack(dropna=False).reset_index().rename(columns={0:f'cnt_{_id}', 'level_0':'d'})
        data = pd.merge(data, f, on=['d', ID])
    
    
    data = fe(ID, data, log=log)

    for key, value in calendar.set_index('d')[['qaurter','wday','month','year','new_event_name_1', 'new_event_type_1','event_name_1','event_type_1']].items():
        data[key] = data.d.map(value)
        if data[key].dtypes==object:
            data[key] = pd.factorize(data[key])[0]

        if key in ['event_name_1','event_type_1']:
            for i in [ -1,1]:
                data[f'{key}_{i}'] = data.groupby(ID)[key].shift(i)
                
    data['snap'] = 0
    for key, value in calendar.set_index('d')[['snap_CA','snap_WI','snap_TX']].items():
        state = key.replace('snap_', '')
        data.loc[data[ID].str.contains(state),'snap'] = data.loc[data[ID].str.contains(state),'d'].map(value)
    for i in [ -1,1]:
        data[f'snap_{i}'] = data.groupby(ID)['snap'].shift(i)
    
    data[f'f_{ID}'] = pd.factorize(data[ID])[0]
    data = data[data.d.isin(trn_d_cols[28:])]
    return data

def make_data_2_id(ID, trn_d_cols, train, price_data, calendar, log=True):
    
    data = train.groupby(ID)[trn_d_cols].sum(min_count=1).T
    data = data.stack(dropna=False).reset_index().rename(columns={0:'TARGET', 'level_0':'d'})
    f = price_data.replace(0,np.nan).groupby(ID)[
        trn_d_cols
    ].count().stack(dropna=False).reset_index().rename(columns={0:'cnt', 'level_1':'d', 'level_0':'d'})
    data = pd.merge(data, f, on=['d', ID])
    
    data = fe(ID, data, log=log)

    for key, value in calendar.set_index('d')[['qaurter','wday','month','year','new_event_name_1', 'new_event_type_1','event_name_1','event_type_1']].items():
        data[key] = data.d.map(value)
        if data[key].dtypes==object:
            data[key] = pd.factorize(data[key])[0]

        if key in ['event_name_1','event_type_1']:
            for i in [ -1,1]:
                data[f'{key}_{i}'] = data.groupby(ID)[key].shift(i)
                
    data['snap'] = 0
    for key, value in calendar.set_index('d')[['snap_CA','snap_WI','snap_TX']].items():
        state = key.replace('snap_', '')
        data.loc[data[ID].str.contains(state),'snap'] = data.loc[data[ID].str.contains(state),'d'].map(value)
    for i in [ -1,1]:
        data[f'snap_{i}'] = data.groupby(ID)['snap'].shift(i)
    
    data[f'f_{ID}'] = pd.factorize(data[ID])[0]
    data = data[data.d.isin(trn_d_cols[28:])]
    return data
# Out:
# 100%|██████████| 30490/30490 [00:11<00:00, 2770.17it/s]

# %% [markdown]
# # lgb model utils

# %%
class Optimize_Optuna():
    def __init__(self, data, ID):
        days = data.d.unique().tolist()
        days = sort_d_cols(days)
        self.trn_days = days[:-28]
        val_days = days[-28:]
        
        self.X = data[data.d.isin(self.trn_days)]
        self.ID = ID
        
        self.shift_cols = [col for col in data.columns if 'shift' in col]
        self.roll_cols = [col for col in data.columns if 'roll' in col]
        cat_cols = [col for col in data.columns if (not 'shift' in col) and (not 'roll' in col)]
        self.cat_cols = [col for col in cat_cols if not col in [ID, 'd', 'TARGET']]
        self.features=self.cat_cols+self.shift_cols+self.roll_cols

    def objective(self, trial):
        PARAMS = {
            'boosting_type': 'gbdt',
            'objective': 'rmse',
            #'tweedie_variance_power': trial.suggest_uniform('tweedie_variance_power', 1.1, 1.9),
            'metric': 'rmse',
            'subsample': trial.suggest_uniform('subsample', 0.4, 0.9),
            'subsample_freq': trial.suggest_uniform('subsample_freq', 0.4, 0.9),
            'learning_rate': trial.suggest_loguniform('learning_rate', 0.03, 0.5),
            'num_leaves': trial.suggest_int('num_leaves', 4, 2**8),
            'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
            'max_bin': 100,
            'n_estimators': 1400,
            'boost_from_average': False,
            'verbose': -1,

            'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
            'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
            'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),

            'random_state':2020
        }
        score = 0

        data = self.X.copy()
        for i in range(28):
            
            if i%7==0:
                data[self.shift_cols] = data.groupby(self.ID)[self.shift_cols].shift(7)
            data[self.roll_cols] = data.groupby(self.ID)[self.roll_cols].shift(1)
            
            split = data[data.d.isin(self.trn_days[-500:])]['TARGET']
            split = split.mean()-3.*split.std()
            X = data[data.TARGET>split]
            X.reset_index(drop=True, inplace=True)
            k = StratifiedKFold(n_splits=8, random_state=2020, shuffle=True)
            
            y = (200*minmax_scale(X['TARGET'])).astype(int)
            t_score=0
            for trn, val in k.split(X,y=y, groups=y):
                train_set = lgb.Dataset(X.loc[trn,self.features], X.loc[trn,'TARGET'])
                val_set = lgb.Dataset(X.loc[val,self.features], X.loc[val,'TARGET'])

                model = lgb.train(train_set=train_set, valid_sets=[train_set, val_set], params=PARAMS, num_boost_round=3000, 
                                  early_stopping_rounds=100, verbose_eval=10000)
                
                preds = model.predict(X.loc[val,self.features])
                
                #preds = np.e**(preds)-1
                #true_y = np.e**(X.loc[val,'TARGET'])-1
                
                true_y = X.loc[val,'TARGET']
                t_score+=np.sqrt(mean_squared_error(preds, true_y))/8
            score+=t_score/28
        return score

# %%
def all_flow(study, n_trials):
    d_cols = [f'd_{i+1}' for i in range(1969)]
    d_cols = d_cols[:-28]
    trn_d_cols = d_cols[-630:]
    #ID='dept_idXstore_id'
    ID='all_id'

    train['dept_idXstore_id'] = train['dept_id'].astype(str)+'X'+train['store_id'].astype(str)
    price_data['dept_idXstore_id'] = train['dept_id'].astype(str)+'X'+train['store_id'].astype(str)
    train['all_id'] = 'all_id'
    price_data['all_id'] = 'all_id'
    
    data = make_data_all_id(ID, trn_d_cols, train, price_data, calendar)
    
    #data = make_data_dept_cat_id(ID=ID, trn_d_cols=trn_d_cols, train=train,
     #                                price_data=price_data, calendar=calendar, log=True)

    optimize_optuna = Optimize_Optuna(data, ID)

    study.optimize(optimize_optuna.objective, n_trials=n_trials)
    return study

# %%
# %%time
#with open(f'../input/fork-of-fork-of-optuna-of-make-data-create-m5-all/study_24times.pickle', 'rb') as f:
 #   study = pickle.load(f)

study = optuna.create_study(direction='minimize')
n_trials=120
study = all_flow(study, n_trials)
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [45]	training's rmse: 8256.45	valid_1's rmse: 9237.47
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [160]	training's rmse: 6396.75	valid_1's rmse: 7443.26
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [261]	training's rmse: 5519.99	valid_1's rmse: 9069.06
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [852]	training's rmse: 3273.09	valid_1's rmse: 8234.49
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [107]	training's rmse: 6941.95	valid_1's rmse: 7358.96
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [90]	training's rmse: 7039.6	valid_1's rmse: 9854.25
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [138]	training's rmse: 6490.56	valid_1's rmse: 8960.73
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [234]	training's rmse: 5636.99	valid_1's rmse: 9145.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [48]	training's rmse: 8153.78	valid_1's rmse: 9237.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [162]	training's rmse: 6490.11	valid_1's rmse: 7744.79
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [329]	training's rmse: 5070.77	valid_1's rmse: 8874.88
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [773]	training's rmse: 3490.86	valid_1's rmse: 8169.08
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [108]	training's rmse: 6948.94	valid_1's rmse: 7051.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [53]	training's rmse: 7839.3	valid_1's rmse: 9821.02
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [131]	training's rmse: 6656.62	valid_1's rmse: 8798.34
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [137]	training's rmse: 6598.07	valid_1's rmse: 9272.02
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [51]	training's rmse: 8011.62	valid_1's rmse: 9311.76
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [159]	training's rmse: 6541.25	valid_1's rmse: 7675.97
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [332]	training's rmse: 5079.11	valid_1's rmse: 8864.52
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [774]	training's rmse: 3465.08	valid_1's rmse: 8182.01
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [123]	training's rmse: 6760.9	valid_1's rmse: 7366.97
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [145]	training's rmse: 6440.07	valid_1's rmse: 9871.42
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [86]	training's rmse: 7297.56	valid_1's rmse: 8804.69
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [242]	training's rmse: 5641.34	valid_1's rmse: 9077.36
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [46]	training's rmse: 8154.54	valid_1's rmse: 9510.25
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [158]	training's rmse: 6557.74	valid_1's rmse: 7815.31
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [98]	training's rmse: 7003.09	valid_1's rmse: 9222.25
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [321]	training's rmse: 5132.56	valid_1's rmse: 8575.74
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [111]	training's rmse: 6926.3	valid_1's rmse: 7391.01
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [105]	training's rmse: 6965.97	valid_1's rmse: 9389.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [102]	training's rmse: 6852.49	valid_1's rmse: 8436.34
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [117]	training's rmse: 6686.8	valid_1's rmse: 9065.15
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [51]	training's rmse: 8002.62	valid_1's rmse: 9355.95
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [115]	training's rmse: 6996.67	valid_1's rmse: 7985.37
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [151]	training's rmse: 6324.61	valid_1's rmse: 9119.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [648]	training's rmse: 3765.83	valid_1's rmse: 8762.73
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [108]	training's rmse: 6946.58	valid_1's rmse: 7445.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [144]	training's rmse: 6439.67	valid_1's rmse: 9713.58
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [301]	training's rmse: 5201.2	valid_1's rmse: 8308.93
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [119]	training's rmse: 6712.59	valid_1's rmse: 9217.25
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [108]	training's rmse: 6923.17	valid_1's rmse: 9146.48
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [117]	training's rmse: 6936.33	valid_1's rmse: 7471.07
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [303]	training's rmse: 5201.26	valid_1's rmse: 9012.88
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [818]	training's rmse: 3386.15	valid_1's rmse: 8356.75
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [62]	training's rmse: 7691.07	valid_1's rmse: 7560.11
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [105]	training's rmse: 6790.91	valid_1's rmse: 9669.14
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [142]	training's rmse: 6388.35	valid_1's rmse: 8370.71
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [233]	training's rmse: 5627.03	valid_1's rmse: 8994.37
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [101]	training's rmse: 6983.63	valid_1's rmse: 9309.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [72]	training's rmse: 7586.3	valid_1's rmse: 7922.52
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [260]	training's rmse: 5626.78	valid_1's rmse: 8910.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [300]	training's rmse: 5337.69	valid_1's rmse: 9003.82
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [82]	training's rmse: 7353.25	valid_1's rmse: 7492.84
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [136]	training's rmse: 6490.96	valid_1's rmse: 9551.86
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [144]	training's rmse: 6475.02	valid_1's rmse: 8746.76
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [147]	training's rmse: 6414.46	valid_1's rmse: 9224.13
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [301]	training's rmse: 5064.75	valid_1's rmse: 8971.21
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [77]	training's rmse: 7568.31	valid_1's rmse: 7522.62
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [150]	training's rmse: 6377.91	valid_1's rmse: 8679.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [768]	training's rmse: 3442.02	valid_1's rmse: 8277.93
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [133]	training's rmse: 6768.56	valid_1's rmse: 7959.26
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [105]	training's rmse: 6774.77	valid_1's rmse: 9656.08
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [308]	training's rmse: 5113.69	valid_1's rmse: 8368.54
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [285]	training's rmse: 5099	valid_1's rmse: 9103.12
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [242]	training's rmse: 5637.06	valid_1's rmse: 9075.75
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [75]	training's rmse: 7738.05	valid_1's rmse: 7632.78
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [119]	training's rmse: 6945.42	valid_1's rmse: 8826.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [328]	training's rmse: 5144.28	valid_1's rmse: 8621.47
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [131]	training's rmse: 6815.29	valid_1's rmse: 7894.83
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [109]	training's rmse: 6743.1	valid_1's rmse: 9802.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [312]	training's rmse: 5212.52	valid_1's rmse: 8051.69
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [81]	training's rmse: 7197.97	valid_1's rmse: 9393.86
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [438]	training's rmse: 4364.08	valid_1's rmse: 8530.77
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [75]	training's rmse: 7569.14	valid_1's rmse: 7786.15
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [209]	training's rmse: 5857.61	valid_1's rmse: 8908.95
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1400]	training's rmse: 2133.09	valid_1's rmse: 7182.07
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [135]	training's rmse: 6702.01	valid_1's rmse: 7872.39
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [55]	training's rmse: 7674.81	valid_1's rmse: 9701.84
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [619]	training's rmse: 3712.11	valid_1's rmse: 7587.69
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [190]	training's rmse: 5882.06	valid_1's rmse: 9017.41
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [241]	training's rmse: 5485.76	valid_1's rmse: 8845.69
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [75]	training's rmse: 7576.14	valid_1's rmse: 7746.85
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [237]	training's rmse: 5604.21	valid_1's rmse: 8813.89
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [591]	training's rmse: 3930.88	valid_1's rmse: 8531.96
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [134]	training's rmse: 6670.32	valid_1's rmse: 8021.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [122]	training's rmse: 6492.36	valid_1's rmse: 9608.08
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [317]	training's rmse: 5105.79	valid_1's rmse: 8126.55
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [110]	training's rmse: 6768.95	valid_1's rmse: 9052.29
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [304]	training's rmse: 5110.23	valid_1's rmse: 9081.96
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [75]	training's rmse: 7585.21	valid_1's rmse: 7934.73
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [120]	training's rmse: 6817.15	valid_1's rmse: 8840.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [591]	training's rmse: 3939.33	valid_1's rmse: 8596.74
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [190]	training's rmse: 6113.57	valid_1's rmse: 7729.45
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [102]	training's rmse: 6926.65	valid_1's rmse: 9627.78
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [357]	training's rmse: 4967.51	valid_1's rmse: 8254
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [116]	training's rmse: 6785.06	valid_1's rmse: 9169.93
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [241]	training's rmse: 5557.36	valid_1's rmse: 9320.38
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [75]	training's rmse: 7593.13	valid_1's rmse: 7869.67
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [238]	training's rmse: 5619.74	valid_1's rmse: 8979.03
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [384]	training's rmse: 4817.29	valid_1's rmse: 8843.53
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [132]	training's rmse: 6684.92	valid_1's rmse: 7564.57
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [315]	training's rmse: 4863.99	valid_1's rmse: 9628.26
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [312]	training's rmse: 5155.57	valid_1's rmse: 8046.04
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [161]	training's rmse: 6131.88	valid_1's rmse: 9066.38
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [194]	training's rmse: 5968.41	valid_1's rmse: 9212.31
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [81]	training's rmse: 7521.31	valid_1's rmse: 7778.92
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [120]	training's rmse: 6925.32	valid_1's rmse: 8734.62
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [507]	training's rmse: 4295.96	valid_1's rmse: 8403.23
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [135]	training's rmse: 6784.43	valid_1's rmse: 7498.79
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [102]	training's rmse: 6811	valid_1's rmse: 9740.77
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [236]	training's rmse: 5693.78	valid_1's rmse: 7970.24
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [116]	training's rmse: 6721.01	valid_1's rmse: 9136.49
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [49]	training's rmse: 8313.94	valid_1's rmse: 9245.36
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [96]	training's rmse: 7384.72	valid_1's rmse: 7617.86
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [330]	training's rmse: 5281.91	valid_1's rmse: 8813.72
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [292]	training's rmse: 5421.82	valid_1's rmse: 9561.53
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [105]	training's rmse: 7235.61	valid_1's rmse: 7325.79
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [105]	training's rmse: 7178.55	valid_1's rmse: 10284.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [243]	training's rmse: 5749.74	valid_1's rmse: 8912.52
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [130]	training's rmse: 6833.94	valid_1's rmse: 9320.03
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [288]	training's rmse: 5376.86	valid_1's rmse: 8853.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [96]	training's rmse: 7335.02	valid_1's rmse: 7519.85
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [348]	training's rmse: 5164.21	valid_1's rmse: 8936.96
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [365]	training's rmse: 4958.37	valid_1's rmse: 9909.21
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [85]	training's rmse: 7578.7	valid_1's rmse: 7472.13
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [53]	training's rmse: 8119.37	valid_1's rmse: 10134.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [351]	training's rmse: 4947.69	valid_1's rmse: 8934.51
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [243]	training's rmse: 5690.27	valid_1's rmse: 9341.57
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [357]	training's rmse: 4946.9	valid_1's rmse: 8705.64
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [90]	training's rmse: 7482.59	valid_1's rmse: 7594.11
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [345]	training's rmse: 5170.19	valid_1's rmse: 9139.59
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [650]	training's rmse: 3760.44	valid_1's rmse: 9049.56
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [58]	training's rmse: 8118.96	valid_1's rmse: 7370.19
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [120]	training's rmse: 6944.98	valid_1's rmse: 10389.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [243]	training's rmse: 5640.87	valid_1's rmse: 8984.32
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [168]	training's rmse: 6367.85	valid_1's rmse: 9636.21
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [357]	training's rmse: 5009.68	valid_1's rmse: 9059.97
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [89]	training's rmse: 7497.33	valid_1's rmse: 7534.03
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [200]	training's rmse: 6161.23	valid_1's rmse: 9236.64
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [234]	training's rmse: 5815.87	valid_1's rmse: 9436.83
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [100]	training's rmse: 7335.86	valid_1's rmse: 7195.54
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [113]	training's rmse: 6987.02	valid_1's rmse: 9865.78
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [228]	training's rmse: 5720.02	valid_1's rmse: 9218.16
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [146]	training's rmse: 6647.46	valid_1's rmse: 9302.08
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [480]	training's rmse: 4307.58	valid_1's rmse: 8840.81
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [132]	training's rmse: 6788.16	valid_1's rmse: 7699.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [203]	training's rmse: 6012.95	valid_1's rmse: 9466.09
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [685]	training's rmse: 3679.86	valid_1's rmse: 8458.62
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [106]	training's rmse: 7307.4	valid_1's rmse: 7485.39
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [117]	training's rmse: 7024.19	valid_1's rmse: 9827.65
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [344]	training's rmse: 4983.05	valid_1's rmse: 9058.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [139]	training's rmse: 6628.6	valid_1's rmse: 9327.25
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [51]	training's rmse: 8229.15	valid_1's rmse: 9306.48
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [115]	training's rmse: 7103.86	valid_1's rmse: 7527.64
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [202]	training's rmse: 6065.37	valid_1's rmse: 8997.27
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [418]	training's rmse: 4687.51	valid_1's rmse: 9123.44
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [107]	training's rmse: 7183.79	valid_1's rmse: 7455.27
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [465]	training's rmse: 4345.52	valid_1's rmse: 9279.55
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [237]	training's rmse: 5682.51	valid_1's rmse: 9208.04
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [157]	training's rmse: 6449.45	valid_1's rmse: 9271.21
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [219]	training's rmse: 5930.04	valid_1's rmse: 8998.92
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [111]	training's rmse: 7247.07	valid_1's rmse: 7493.44
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [297]	training's rmse: 5405.76	valid_1's rmse: 9115.17
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [330]	training's rmse: 5129.61	valid_1's rmse: 9317.34
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [51]	training's rmse: 8346.26	valid_1's rmse: 7626.66
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [383]	training's rmse: 4769.04	valid_1's rmse: 9499.52
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [203]	training's rmse: 5870.21	valid_1's rmse: 8864.89
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [243]	training's rmse: 5630.97	valid_1's rmse: 9336.72
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [351]	training's rmse: 4809.89	valid_1's rmse: 8978.16
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [796]	training's rmse: 3125.19	valid_1's rmse: 6816.53
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [119]	training's rmse: 6709.66	valid_1's rmse: 8890.44
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [328]	training's rmse: 4909.83	valid_1's rmse: 8468.09
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [519]	training's rmse: 3964.13	valid_1's rmse: 7412.63
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [113]	training's rmse: 6590.51	valid_1's rmse: 9518.77
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [743]	training's rmse: 3376.6	valid_1's rmse: 7592.13
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [116]	training's rmse: 6732.36	valid_1's rmse: 9608.64
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [194]	training's rmse: 5889.27	valid_1's rmse: 9264.04
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [454]	training's rmse: 4368.07	valid_1's rmse: 6517.79
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [120]	training's rmse: 6742.08	valid_1's rmse: 9018.68
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [327]	training's rmse: 4930.15	valid_1's rmse: 8661.52
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [125]	training's rmse: 6674.12	valid_1's rmse: 7607.92
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [110]	training's rmse: 6706.68	valid_1's rmse: 9523.51
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [566]	training's rmse: 3827.2	valid_1's rmse: 7962.56
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [285]	training's rmse: 4988.43	valid_1's rmse: 9196.3
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [131]	training's rmse: 6498.84	valid_1's rmse: 9143.95
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [453]	training's rmse: 4308.02	valid_1's rmse: 6627.11
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [118]	training's rmse: 6714.82	valid_1's rmse: 8845.31
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [507]	training's rmse: 3901.42	valid_1's rmse: 8433.17
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [199]	training's rmse: 5811.27	valid_1's rmse: 7399.91
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [386]	training's rmse: 4230.54	valid_1's rmse: 8934.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [580]	training's rmse: 3757.84	valid_1's rmse: 8029.42
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [119]	training's rmse: 6523.9	valid_1's rmse: 9457.45
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [140]	training's rmse: 6519.06	valid_1's rmse: 9009.43
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [912]	training's rmse: 2943.89	valid_1's rmse: 6730.4
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [119]	training's rmse: 6759.48	valid_1's rmse: 8935.43
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [330]	training's rmse: 4843.04	valid_1's rmse: 8350.98
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [134]	training's rmse: 6681.34	valid_1's rmse: 7653.34
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [315]	training's rmse: 4759.07	valid_1's rmse: 9175.22
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [311]	training's rmse: 5001.13	valid_1's rmse: 8347.57
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [293]	training's rmse: 4983.47	valid_1's rmse: 9741.65
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [132]	training's rmse: 6538.91	valid_1's rmse: 9043.15
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [435]	training's rmse: 4365.56	valid_1's rmse: 6954.48
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [119]	training's rmse: 6683.78	valid_1's rmse: 9001.63
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [365]	training's rmse: 4617.63	valid_1's rmse: 7976.65
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [113]	training's rmse: 6970.65	valid_1's rmse: 7495.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [165]	training's rmse: 6040.26	valid_1's rmse: 9592.75
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [567]	training's rmse: 3861.07	valid_1's rmse: 7671.56
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [114]	training's rmse: 6774.67	valid_1's rmse: 9162.46
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [126]	training's rmse: 6648.84	valid_1's rmse: 8906.72
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [780]	training's rmse: 3153.61	valid_1's rmse: 6912.11
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [141]	training's rmse: 6425.93	valid_1's rmse: 9065.04
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [672]	training's rmse: 3402.99	valid_1's rmse: 8020.78
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [332]	training's rmse: 4794.4	valid_1's rmse: 7233.98
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [389]	training's rmse: 4214.68	valid_1's rmse: 9371.27
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1070]	training's rmse: 2569.43	valid_1's rmse: 7404.92
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [282]	training's rmse: 5130.42	valid_1's rmse: 9052.06
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [357]	training's rmse: 4786.46	valid_1's rmse: 8503.68
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [821]	training's rmse: 3130.54	valid_1's rmse: 6707.14
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [139]	training's rmse: 6431.82	valid_1's rmse: 8699.15
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [673]	training's rmse: 3476.51	valid_1's rmse: 7990.47
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [113]	training's rmse: 6820.68	valid_1's rmse: 7340.03
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [57]	training's rmse: 7744.36	valid_1's rmse: 9949.33
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1400]	training's rmse: 2097.02	valid_1's rmse: 7514.78
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [464]	training's rmse: 4104.07	valid_1's rmse: 9108.84
# [I 2020-06-20 17:42:55,255] Finished trial#0 with value: 8610.295793518226 with parameters: {'subsample': 0.7205823350381939, 'subsample_freq': 0.7775324877370502, 'learning_rate': 0.1053618409823162, 'num_leaves': 161, 'feature_fraction': 0.8120820774440378, 'bagging_freq': 3, 'min_child_samples': 77, 'lambda_l1': 6.221405742074153e-08, 'lambda_l2': 6.380707811495632e-07}. Best is trial#0 with value: 8610.295793518226.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [14]	training's rmse: 7291.09	valid_1's rmse: 9361.33
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [54]	training's rmse: 4906.92	valid_1's rmse: 7461.89
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [63]	training's rmse: 4487.65	valid_1's rmse: 8769.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [239]	training's rmse: 1513.32	valid_1's rmse: 8531.63
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [19]	training's rmse: 7206.16	valid_1's rmse: 7555.93
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's rmse: 6624.13	valid_1's rmse: 9343.12
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [13]	training's rmse: 8001.45	valid_1's rmse: 9288.01
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [63]	training's rmse: 4452.47	valid_1's rmse: 10033.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's rmse: 6779.48	valid_1's rmse: 9311.62
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [15]	training's rmse: 7827.76	valid_1's rmse: 7547.33
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [40]	training's rmse: 5393.89	valid_1's rmse: 8367.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [275]	training's rmse: 1270.28	valid_1's rmse: 8094.68
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [51]	training's rmse: 5100.45	valid_1's rmse: 7020.21
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [54]	training's rmse: 4664.76	valid_1's rmse: 9291.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [106]	training's rmse: 3260.34	valid_1's rmse: 8780.9
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [67]	training's rmse: 4399.65	valid_1's rmse: 9642.21
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	training's rmse: 6401.79	valid_1's rmse: 9097.55
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's rmse: 7260.33	valid_1's rmse: 7189.44
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [31]	training's rmse: 5950.33	valid_1's rmse: 8454.48
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [164]	training's rmse: 2266.65	valid_1's rmse: 7950.01
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [48]	training's rmse: 5082.46	valid_1's rmse: 7563.77
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [67]	training's rmse: 4268.73	valid_1's rmse: 8365.27
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	training's rmse: 6486.07	valid_1's rmse: 8190.69
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [141]	training's rmse: 2518.94	valid_1's rmse: 9428.48
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	training's rmse: 6027.21	valid_1's rmse: 8989.41
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [111]	training's rmse: 3223.91	valid_1's rmse: 7504.92
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [35]	training's rmse: 5762.43	valid_1's rmse: 7989.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [279]	training's rmse: 1222.92	valid_1's rmse: 7775.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [18]	training's rmse: 7203.45	valid_1's rmse: 7634.17
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [68]	training's rmse: 4307.7	valid_1's rmse: 8830.59
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [55]	training's rmse: 4793.53	valid_1's rmse: 8925.56
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [107]	training's rmse: 3208.91	valid_1's rmse: 9672.02
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [55]	training's rmse: 4634.42	valid_1's rmse: 8788.73
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [25]	training's rmse: 6546.48	valid_1's rmse: 7194.65
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [40]	training's rmse: 5517.57	valid_1's rmse: 8088.41
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [239]	training's rmse: 1505.5	valid_1's rmse: 7914.43
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	training's rmse: 6702.32	valid_1's rmse: 7495.73
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [70]	training's rmse: 4264.14	valid_1's rmse: 8675.09
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [57]	training's rmse: 4728.9	valid_1's rmse: 8433
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [63]	training's rmse: 4409.33	valid_1's rmse: 9502.65
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [17]	training's rmse: 6838.53	valid_1's rmse: 9002.18
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's rmse: 7167.27	valid_1's rmse: 7192.42
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [61]	training's rmse: 4469.22	valid_1's rmse: 8448.32
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [218]	training's rmse: 1669.13	valid_1's rmse: 8395.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [28]	training's rmse: 6370.21	valid_1's rmse: 7610.93
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [161]	training's rmse: 2316.11	valid_1's rmse: 8848.07
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	training's rmse: 4037.06	valid_1's rmse: 8643.45
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [64]	training's rmse: 4410.77	valid_1's rmse: 9697.87
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	training's rmse: 6288.22	valid_1's rmse: 8916.39
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [59]	training's rmse: 4714.27	valid_1's rmse: 7505.39
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [40]	training's rmse: 5396.45	valid_1's rmse: 8674.65
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [122]	training's rmse: 3103.52	valid_1's rmse: 7818.21
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's rmse: 6927.58	valid_1's rmse: 7873.22
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [68]	training's rmse: 4279.8	valid_1's rmse: 9014.23
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [40]	training's rmse: 5634.33	valid_1's rmse: 8638.74
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [63]	training's rmse: 4526.85	valid_1's rmse: 9766.76
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [116]	training's rmse: 2881.03	valid_1's rmse: 9507.17
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [15]	training's rmse: 7685.67	valid_1's rmse: 6913.17
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [19]	training's rmse: 6762.48	valid_1's rmse: 8932.42
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [853]	training's rmse: 349.779	valid_1's rmse: 8327.03
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [24]	training's rmse: 6536.12	valid_1's rmse: 7448.42
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's rmse: 6442.05	valid_1's rmse: 9105.64
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [85]	training's rmse: 4037.19	valid_1's rmse: 7763.61
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [46]	training's rmse: 4950.57	valid_1's rmse: 8939
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [25]	training's rmse: 6362.87	valid_1's rmse: 9811.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [208]	training's rmse: 1813.36	valid_1's rmse: 6849.33
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [19]	training's rmse: 6783.64	valid_1's rmse: 8955.72
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [57]	training's rmse: 4694.92	valid_1's rmse: 8571.04
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [17]	training's rmse: 7196.49	valid_1's rmse: 7511.41
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [17]	training's rmse: 6778.6	valid_1's rmse: 9045.94
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [111]	training's rmse: 3355.42	valid_1's rmse: 7921.67
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [40]	training's rmse: 5264.7	valid_1's rmse: 9138.51
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [37]	training's rmse: 5595.41	valid_1's rmse: 9044.62
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [16]	training's rmse: 7465.85	valid_1's rmse: 7064.86
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [19]	training's rmse: 6816.59	valid_1's rmse: 8724.19
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [838]	training's rmse: 339.549	valid_1's rmse: 7126.13
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [42]	training's rmse: 5409.72	valid_1's rmse: 7234.23
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [56]	training's rmse: 4312.2	valid_1's rmse: 9336.38
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [60]	training's rmse: 4874.15	valid_1's rmse: 7509.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [63]	training's rmse: 4320.58	valid_1's rmse: 8902.54
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [38]	training's rmse: 5491.6	valid_1's rmse: 9708.73
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [15]	training's rmse: 7609.64	valid_1's rmse: 6927.74
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	training's rmse: 3914.02	valid_1's rmse: 8741.19
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [952]	training's rmse: 349.337	valid_1's rmse: 7759.63
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [28]	training's rmse: 6185.18	valid_1's rmse: 7036.58
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [59]	training's rmse: 4498.41	valid_1's rmse: 8674.62
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [112]	training's rmse: 3300.81	valid_1's rmse: 7629.38
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [50]	training's rmse: 4851.35	valid_1's rmse: 8556.85
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [132]	training's rmse: 2754.39	valid_1's rmse: 9735.15
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# ...
# Early stopping, best iteration is:
# [100]	training's rmse: 4638.13	valid_1's rmse: 6932.46
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [277]	training's rmse: 1959.71	valid_1's rmse: 7815.25
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [507]	training's rmse: 906.941	valid_1's rmse: 7898.03
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [116]	training's rmse: 4069.17	valid_1's rmse: 7155.36
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [88]	training's rmse: 5100.05	valid_1's rmse: 8104.86
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [146]	training's rmse: 3433.7	valid_1's rmse: 8106.94
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [317]	training's rmse: 1627.68	valid_1's rmse: 8882.59
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [108]	training's rmse: 4180.04	valid_1's rmse: 9059.22
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [122]	training's rmse: 4165.06	valid_1's rmse: 6737.06
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [198]	training's rmse: 2720.19	valid_1's rmse: 7771.02
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [731]	training's rmse: 447.64	valid_1's rmse: 8074.75
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [143]	training's rmse: 3672.99	valid_1's rmse: 6985.03
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [117]	training's rmse: 4148.78	valid_1's rmse: 8058.57
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [109]	training's rmse: 4253.93	valid_1's rmse: 8200.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [254]	training's rmse: 2068.75	valid_1's rmse: 9239.39
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [107]	training's rmse: 4219.68	valid_1's rmse: 8906.88
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [126]	training's rmse: 4108.72	valid_1's rmse: 6677.79
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [234]	training's rmse: 2317.17	valid_1's rmse: 8140.61
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [911]	training's rmse: 286.66	valid_1's rmse: 7596.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [113]	training's rmse: 4300.32	valid_1's rmse: 7144.85
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [115]	training's rmse: 4213.43	valid_1's rmse: 8114.16
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [145]	training's rmse: 3508.88	valid_1's rmse: 8030.45
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [250]	training's rmse: 2173.53	valid_1's rmse: 9154.77
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [95]	training's rmse: 4540.16	valid_1's rmse: 9074.12
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [127]	training's rmse: 4077.77	valid_1's rmse: 6604.59
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [228]	training's rmse: 2358.41	valid_1's rmse: 7964.48
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [865]	training's rmse: 325.779	valid_1's rmse: 7646.55
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [140]	training's rmse: 3665.58	valid_1's rmse: 7028.27
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [266]	training's rmse: 1986.89	valid_1's rmse: 8127.58
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [846]	training's rmse: 340.974	valid_1's rmse: 7682.2
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [250]	training's rmse: 2101.77	valid_1's rmse: 8966.53
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [128]	training's rmse: 3652.88	valid_1's rmse: 8718.24
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [119]	training's rmse: 4202.06	valid_1's rmse: 6767.18
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [203]	training's rmse: 2656	valid_1's rmse: 7700.58
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1065]	training's rmse: 212.682	valid_1's rmse: 7573.81
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [143]	training's rmse: 3556.69	valid_1's rmse: 7021.35
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [116]	training's rmse: 4140.34	valid_1's rmse: 8088.42
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [122]	training's rmse: 3995.49	valid_1's rmse: 7848.67
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [196]	training's rmse: 2717.47	valid_1's rmse: 9303.29
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [106]	training's rmse: 4162.51	valid_1's rmse: 8790.12
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [122]	training's rmse: 4121.63	valid_1's rmse: 6950.36
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [625]	training's rmse: 569.8	valid_1's rmse: 7604.5
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [709]	training's rmse: 459.668	valid_1's rmse: 7288.57
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [105]	training's rmse: 4407.04	valid_1's rmse: 7200.57
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [425]	training's rmse: 1085.85	valid_1's rmse: 7651.78
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [152]	training's rmse: 3383.79	valid_1's rmse: 8001.18
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [471]	training's rmse: 926.579	valid_1's rmse: 8829.7
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [105]	training's rmse: 4159.31	valid_1's rmse: 8628.31
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [109]	training's rmse: 4431.41	valid_1's rmse: 6940.27
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [258]	training's rmse: 2076.47	valid_1's rmse: 7674.77
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [901]	training's rmse: 288.559	valid_1's rmse: 7666.14
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [118]	training's rmse: 4043.84	valid_1's rmse: 7022.6
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [153]	training's rmse: 3300.04	valid_1's rmse: 7562.36
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [684]	training's rmse: 467.05	valid_1's rmse: 7670.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [156]	training's rmse: 3241.83	valid_1's rmse: 8872.46
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [746]	training's rmse: 420.804	valid_1's rmse: 8542.18
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [183]	training's rmse: 2932.52	valid_1's rmse: 6651.67
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [190]	training's rmse: 2782.66	valid_1's rmse: 8616.99
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [881]	training's rmse: 341.831	valid_1's rmse: 7069.51
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [126]	training's rmse: 3866.2	valid_1's rmse: 6727.77
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [102]	training's rmse: 4425.83	valid_1's rmse: 8473.06
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [150]	training's rmse: 3399.03	valid_1's rmse: 7422.69
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [225]	training's rmse: 2347.95	valid_1's rmse: 8594.11
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [319]	training's rmse: 1566.03	valid_1's rmse: 9034.33
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [120]	training's rmse: 4085.63	valid_1's rmse: 6538.02
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [202]	training's rmse: 2601.74	valid_1's rmse: 8517.69
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [579]	training's rmse: 702.091	valid_1's rmse: 6984.05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [262]	training's rmse: 2133.24	valid_1's rmse: 6612.03
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [89]	training's rmse: 4984.42	valid_1's rmse: 8409.96
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [106]	training's rmse: 4312.09	valid_1's rmse: 7643.44
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [201]	training's rmse: 2682.64	valid_1's rmse: 8734.89
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [775]	training's rmse: 368.939	valid_1's rmse: 8736.87
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [123]	training's rmse: 3942.9	valid_1's rmse: 6872.86
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [167]	training's rmse: 3032.67	valid_1's rmse: 8450.69
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1400]	training's rmse: 143.871	valid_1's rmse: 6445.67
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [150]	training's rmse: 3446.96	valid_1's rmse: 6881.24
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [88]	training's rmse: 5004.68	valid_1's rmse: 8520.27
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [150]	training's rmse: 3427.63	valid_1's rmse: 7565.23
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [240]	training's rmse: 2278.68	valid_1's rmse: 8604.11
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [104]	training's rmse: 4258.18	valid_1's rmse: 9014.31
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [112]	training's rmse: 4284.53	valid_1's rmse: 6606.1
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [189]	training's rmse: 2783.58	valid_1's rmse: 8597.95
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1400]	training's rmse: 159.149	valid_1's rmse: 7168.73
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [144]	training's rmse: 3574.74	valid_1's rmse: 6633.04
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [90]	training's rmse: 4904.1	valid_1's rmse: 8461.34
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [380]	training's rmse: 1307.63	valid_1's rmse: 7479.71
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [150]	training's rmse: 3399.48	valid_1's rmse: 8767.11
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [261]	training's rmse: 1933.53	valid_1's rmse: 9126.16
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [122]	training's rmse: 4058	valid_1's rmse: 6848.17
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [201]	training's rmse: 2649.89	valid_1's rmse: 8670.43
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [383]	training's rmse: 1283.26	valid_1's rmse: 7020.71
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [319]	training's rmse: 1666.23	valid_1's rmse: 6828.09
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [99]	training's rmse: 4561.68	valid_1's rmse: 8187.24
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [200]	training's rmse: 2644.05	valid_1's rmse: 7438.05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [438]	training's rmse: 1048.64	valid_1's rmse: 8579.96
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [294]	training's rmse: 1743.41	valid_1's rmse: 8958.97
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [180]	training's rmse: 3015.87	valid_1's rmse: 6875
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [153]	training's rmse: 3377.59	valid_1's rmse: 8845.26
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1400]	training's rmse: 186.905	valid_1's rmse: 7095.05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [149]	training's rmse: 3459	valid_1's rmse: 6612.68
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [93]	training's rmse: 4809.09	valid_1's rmse: 8326.8
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [160]	training's rmse: 3292.74	valid_1's rmse: 7429.81
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [220]	training's rmse: 2392.28	valid_1's rmse: 8473.15
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [295]	training's rmse: 1736.09	valid_1's rmse: 8826.49
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [115]	training's rmse: 4166.78	valid_1's rmse: 6742.29
# Training until validation scores don't improve for 100 rounds

# %%
print(f"""
Number of finished trials :     {len(study.trials)}
Best value                :  {study.best_value :.3f}
""")

print('Best trial:', study.best_trial.params)
# Out:
# Number of finished trials :     120
# Best value                :  7712.523
#
# Best trial: {'subsample': 0.8980424161870934, 'subsample_freq': 0.6061652675361959, 'learning_rate': 0.04371615591331765, 'num_leaves': 213, 'feature_fraction': 0.7997065596025078, 'bagging_freq': 5, 'min_child_samples': 24, 'lambda_l1': 2.693536203464105e-06, 'lambda_l2': 0.0021954225706444447}

# %%
a = len(study.trials)
with open(f'study_{a}times.pickle', 'wb') as f:
    pickle.dump(study, f)
